# %%
import pandas as pd
import numpy as np

# %%
mca = pd.read_csv("marketing_customer_analysis.csv")
mca
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# ...

# %%
mca.dtypes
# Out:
# Unnamed: 0                         int64
# Customer                          object
# State                             object
# Customer Lifetime Value          float64
# Response                          object
# Coverage                          object
# Education                         object
# Effective To Date                 object
# EmploymentStatus                  object
# Gender                            object
# Income                             int64
# Location Code                     object
# Marital Status                    object
# Monthly Premium Auto               int64
# Months Since Last Claim          float64
# Months Since Policy Inception      int64
# Number of Open Complaints        float64
# Number of Policies                 int64
# Policy Type                       object
# Policy                            object
# Renew Offer Type                  object
# Sales Channel                     object
# Total Claim Amount               float64
# ...

# %%
mca.describe().T
# Out:
#                                  count          mean           std  \
# Unnamed: 0                     10910.0   5454.500000   3149.590053
# Customer Lifetime Value        10910.0   8018.241094   6885.081434
# Income                         10910.0  37536.284785  30359.195670
# Monthly Premium Auto           10910.0     93.196059     34.442532
# Months Since Last Claim        10277.0     15.149071     10.080349
# Months Since Policy Inception  10910.0     48.091934     27.940675
# Number of Open Complaints      10277.0      0.384256      0.912457
# Number of Policies             10910.0      2.979193      2.399359
# Total Claim Amount             10910.0    434.888330    292.180556
#
#                                        min          25%           50%  \
# Unnamed: 0                        0.000000  2727.250000   5454.500000
# Customer Lifetime Value        1898.007675  4014.453113   5771.147235
# Income                            0.000000     0.000000  33813.500000
# ...

# %%
mca1 =mca.drop(["Unnamed: 0"], axis=1)
mca1
# Out:
#       Customer       State  Customer Lifetime Value Response  Coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       Education Effective To Date EmploymentStatus Gender  Income  ...  \
# ...

# %%
mca1.columns = list(map(lambda x: str.lower(x), mca1.columns))

mca1.columns
# Out:
# Index(['customer', 'state', 'customer lifetime value', 'response', 'coverage',
#        'education', 'effective to date', 'employmentstatus', 'gender',
#        'income', 'location code', 'marital status', 'monthly premium auto',
#        'months since last claim', 'months since policy inception',
#        'number of open complaints', 'number of policies', 'policy type',
#        'policy', 'renew offer type', 'sales channel', 'total claim amount',
#        'vehicle class', 'vehicle size', 'vehicle type'],
#       dtype='object')

# %%
mca1.isna().sum()
# Out:
# customer                            0
# state                             631
# customer lifetime value             0
# response                          631
# coverage                            0
# education                           0
# effective to date                   0
# employmentstatus                    0
# gender                              0
# income                              0
# location code                       0
# marital status                      0
# monthly premium auto                0
# months since last claim           633
# months since policy inception       0
# number of open complaints         633
# number of policies                  0
# policy type                         0
# policy                              0
# renew offer type                    0
# sales channel                       0
# total claim amount                  0
# vehicle class                     622
# vehicle size                      622
# vehicle type                     5482
# ...

# %%
mca1["state"].value_counts(dropna=False)
# Out:
# California    3552
# Oregon        2909
# Arizona       1937
# Nevada         993
# Washington     888
# NaN            631
# Name: state, dtype: int64

# %%
# in this instance we decided to fill NaN with unknown, as 631 values are a 1/6 of Califorina for instance and that change could impare our analysis

# %%
mca1["response"].value_counts(dropna=False)
# Out:
# No     8813
# Yes    1466
# NaN     631
# Name: response, dtype: int64

# %%
mca1["response"] = mca1["response"].fillna("No")
mca1["response"].value_counts(dropna=False)
# Out:
# No     9444
# Yes    1466
# Name: response, dtype: int64

# %%
mca1["months since last claim"].value_counts(dropna=False)
# Out:
# NaN     633
# 3.0     426
# 6.0     394
# 1.0     386
# 7.0     378
# 4.0     373
# 2.0     368
# 5.0     355
# 0.0     354
# 10.0    346
# 16.0    333
# 11.0    331
# 15.0    323
# 13.0    320
# 8.0     315
# 12.0    307
# 17.0    299
# 14.0    299
# 9.0     277
# 19.0    276
# 23.0    276
# 25.0    269
# 21.0    267
# 18.0    257
# 20.0    254
# 22.0    246
# 24.0    237
# 29.0    234
# 28.0    227
# 31.0    221
# 26.0    211
# 27.0    208
# 30.0    201
# 34.0    199
# 33.0    198
# 35.0    157
# 32.0    155
# Name: months since last claim, dtype: int64

# %%
mca1["number of open complaints"].value_counts(dropna=False)
# Out:
# 0.0    8160
# 1.0    1145
# NaN     633
# 2.0     414
# 3.0     324
# 4.0     166
# 5.0      68
# Name: number of open complaints, dtype: int64

# %%
# we are going to assign the Nan values to 0.0 as it is the highest number in that column
mca1["number of open complaints"] = mca1["number of open complaints"].fillna("0")
mca1["number of open complaints"].value_counts(dropna=False)
# Out:
# 0.0    8160
# 1.0    1145
# 0       633
# 2.0     414
# 3.0     324
# 4.0     166
# 5.0      68
# Name: number of open complaints, dtype: int64

# %%
mca1["vehicle class"].value_counts(dropna=False)
# Out:
# Four-Door Car    5212
# Two-Door Car     2118
# SUV              2012
# NaN               622
# Sports Car        550
# Luxury SUV        208
# Luxury Car        188
# Name: vehicle class, dtype: int64

# %%
# we are going to assign the Nan values to four-Door class as it is the highest number in that column
mca1["vehicle class"] = mca1["vehicle class"].fillna("Four-Door Car")
mca1["vehicle class"].value_counts(dropna=False)
# Out:
# Four-Door Car    5834
# Two-Door Car     2118
# SUV              2012
# Sports Car        550
# Luxury SUV        208
# Luxury Car        188
# Name: vehicle class, dtype: int64

# %%
mca1["vehicle size"].value_counts(dropna=False)
# Out:
# Medsize    7251
# Small      1966
# Large      1071
# NaN         622
# Name: vehicle size, dtype: int64

# %%
# we are going to assign the Nan values to Medsize class as it is the highest number in that column
mca1["vehicle size"] = mca1["vehicle size"].fillna("Medsize")
mca1["vehicle size"].value_counts(dropna=False)
# Out:
# Medsize    7873
# Small      1966
# Large      1071
# Name: vehicle size, dtype: int64

# %%
mca1["vehicle type"].value_counts(dropna=False)
# Out:
# NaN    5482
# A      5428
# Name: vehicle type, dtype: int64

# %%
# we are going to assign the Nan values to A  as it is the highest number in that column
mca1["vehicle type"] = mca1["vehicle type"].fillna("A")
mca1["vehicle type"].value_counts(dropna=False)
# Out:
# A    10910
# Name: vehicle type, dtype: int64

# %%
import time
from datetime import date
mca1
# Out:
#       customer       state  customer lifetime value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928       No     Basic
#
#       education effective to date employmentstatus gender  income  ...  \
# ...

# %%
mca1q1 = mca1['effective to date']

# %%
mca1q1
# Out:
# 0        2/18/11
# 1        1/18/11
# 2        2/10/11
# 3        1/11/11
# 4        1/17/11
#           ...
# 10905    1/19/11
# 10906     1/6/11
# 10907     2/6/11
# 10908    2/13/11
# 10909     1/8/11
# Name: effective to date, Length: 10910, dtype: object

# %%
mca1['effective to date'] = pd.to_datetime(mca1['effective to date'], errors='coerce') 
mca1
# Out:
#       customer       state  customer lifetime value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928       No     Basic
#
#       education effective to date employmentstatus gender  income  ...  \
# ...

# %%
mca1.dtypes
# Out:
# customer                                 object
# state                                    object
# customer lifetime value                 float64
# response                                 object
# coverage                                 object
# education                                object
# effective to date                datetime64[ns]
# employmentstatus                         object
# gender                                   object
# income                                    int64
# location code                            object
# marital status                           object
# monthly premium auto                      int64
# months since last claim                 float64
# months since policy inception             int64
# number of open complaints                object
# number of policies                        int64
# policy type                              object
# policy                                   object
# renew offer type                         object
# ...

# %%
# the column effective to date is formated in proper dates.

mca1["effective to date"].dt.month
# Out:
# 0        2
# 1        1
# 2        2
# 3        1
# 4        1
#         ..
# 10905    1
# 10906    1
# 10907    2
# 10908    2
# 10909    1
# Name: effective to date, Length: 10910, dtype: int64

# %%
mca1.month = mca1["effective to date"].dt.month
mca1.month.value_counts()
# Out:
# C:\Users\Emmanuel\AppData\Local\Temp\ipykernel_25736\1040316362.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   mca1.month = mca1["effective to date"].dt.month
# 1    5818
# 2    5092
# Name: effective to date, dtype: int64

# %%
mca1
# Out:
#       customer       state  customer lifetime value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928       No     Basic
#
#       education effective to date employmentstatus gender  income  ...  \
# ...

# %%
mca1["months"] = mca1["effective to date"].dt.month
mca1
# Out:
#       customer       state  customer lifetime value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928       No     Basic
#
#       education effective to date employmentstatus gender  income  ...  \
# ...

# %%
# ##############################################################Activity 3########################################################""
